# %%
import pandas as pd
import pickle

# %%
df1 = pd.read_csv('Data_train_test/Test1.csv')
df2 = pd.read_csv('Data_train_test/Test2.csv')
df3 = pd.read_csv('Data_train_test/Test3.csv')
df4 = pd.read_csv('Data_train_test/Test4.csv')

# %%
df = pd.concat([df1,df2,df3,df4])
df
# Out:
#        Cycle   OpSet1  OpSet2  OpSet3     SM1     SM2      SM3      SM4  \
# 0          1   0.0023  0.0003     100  518.67  643.02  1585.29  1398.21
# 1          2  -0.0027 -0.0003     100  518.67  641.71  1588.45  1395.42
# 2          3   0.0003  0.0001     100  518.67  642.46  1586.94  1401.34
# 3          4   0.0042  0.0000     100  518.67  642.44  1584.12  1406.42
# 4          5   0.0014  0.0000     100  518.67  642.51  1587.19  1401.92
# ...      ...      ...     ...     ...     ...     ...      ...      ...
# 41209    277  41.9991  0.8401     100  445.00  550.30  1364.40  1129.17
# 41210    278  20.0026  0.7005     100  491.19  608.00  1494.75  1260.88
# 41211    279  34.9988  0.8413     100  449.44  555.92  1370.65  1130.97
# 41212    280  20.0027  0.7000     100  491.19  608.19  1489.11  1256.25
# 41213    281  35.0075  0.8402     100  449.44  556.40  1378.58  1140.70
#
#          SM5    SM6  ...     SM13     SM14    SM15  SM16  SM17  SM18   SM19  \
# ...

# %%
uf_columns = ['OpSet1','OpSet2','OpSet3','SM1','SM5','SM6','SM9','SM10','SM14','SM16','SM18','SM19']

# %%
n_df = df.drop(columns=uf_columns)

# %%
n_df
# Out:
#        Cycle     SM2      SM3      SM4     SM7      SM8   SM11    SM12  \
# 0          1  643.02  1585.29  1398.21  553.90  2388.04  47.20  521.72
# 1          2  641.71  1588.45  1395.42  554.85  2388.01  47.50  522.16
# 2          3  642.46  1586.94  1401.34  554.11  2388.05  47.50  521.97
# 3          4  642.44  1584.12  1406.42  554.07  2388.03  47.28  521.38
# 4          5  642.51  1587.19  1401.92  554.16  2388.01  47.31  522.15
# ...      ...     ...      ...      ...     ...      ...    ...     ...
# 41209    277  550.30  1364.40  1129.17  138.34  2212.35  42.30  130.87
# 41210    278  608.00  1494.75  1260.88  334.75  2324.23  44.53  314.51
# 41211    279  555.92  1370.65  1130.97  194.92  2223.57  42.33  182.76
# 41212    280  608.19  1489.11  1256.25  333.15  2324.19  44.78  314.17
# 41213    281  556.40  1378.58  1140.70  194.26  2223.50  42.08  181.88
#
#           SM13    SM15  SM17   SM20     SM21  labels
# 0      2388.03  8.4052   392  38.86  23.3735       0
# ...

# %%
X_test = n_df.iloc[:,0:-1]
y_test = n_df.iloc[:,-1]

# %%
X_test
# Out:
#        Cycle     SM2      SM3      SM4     SM7      SM8   SM11    SM12  \
# 0          1  643.02  1585.29  1398.21  553.90  2388.04  47.20  521.72
# 1          2  641.71  1588.45  1395.42  554.85  2388.01  47.50  522.16
# 2          3  642.46  1586.94  1401.34  554.11  2388.05  47.50  521.97
# 3          4  642.44  1584.12  1406.42  554.07  2388.03  47.28  521.38
# 4          5  642.51  1587.19  1401.92  554.16  2388.01  47.31  522.15
# ...      ...     ...      ...      ...     ...      ...    ...     ...
# 41209    277  550.30  1364.40  1129.17  138.34  2212.35  42.30  130.87
# 41210    278  608.00  1494.75  1260.88  334.75  2324.23  44.53  314.51
# 41211    279  555.92  1370.65  1130.97  194.92  2223.57  42.33  182.76
# 41212    280  608.19  1489.11  1256.25  333.15  2324.19  44.78  314.17
# 41213    281  556.40  1378.58  1140.70  194.26  2223.50  42.08  181.88
#
#           SM13    SM15  SM17   SM20     SM21
# 0      2388.03  8.4052   392  38.86  23.3735
# ...

# %%
model = pickle.load(open('Model.pickle','rb'))

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8962601409001211
