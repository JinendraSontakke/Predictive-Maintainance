# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# reading all the training file
df1 = pd.read_csv("Data_train_test/train_1.csv")
df2 = pd.read_csv("Data_train_test/train_2.csv")
df3 = pd.read_csv("Data_train_test/train_3.csv")
df4 = pd.read_csv("Data_train_test/train_4.csv")

# %%
# concat all df into one 
df = pd.concat([df1,df2,df3,df4])
df
# Out:
#        Cycle   OpSet1  OpSet2  OpSet3     SM1     SM2      SM3      SM4  \
# 0          1  -0.0007 -0.0004   100.0  518.67  641.82  1589.70  1400.60
# 1          2   0.0019 -0.0003   100.0  518.67  642.15  1591.82  1403.14
# 2          3  -0.0043  0.0003   100.0  518.67  642.35  1587.99  1404.20
# 3          4   0.0007  0.0000   100.0  518.67  642.35  1582.79  1401.87
# 4          5  -0.0019 -0.0002   100.0  518.67  642.37  1582.85  1406.22
# ...      ...      ...     ...     ...     ...     ...      ...      ...
# 61244    251   9.9998  0.2500   100.0  489.05  605.33  1516.36  1315.28
# 61245    252   0.0028  0.0015   100.0  518.67  643.42  1598.92  1426.77
# 61246    253   0.0029  0.0000   100.0  518.67  643.68  1607.72  1430.56
# 61247    254  35.0046  0.8400   100.0  449.44  555.77  1381.29  1148.18
# 61248    255  42.0030  0.8400   100.0  445.00  549.85  1369.75  1147.45
#
#          SM5    SM6  ...     SM13     SM14    SM15  SrM16  SM17  SM18   SM19  \
# ...

# %%
uf_columns = ['OpSet1','OpSet2','OpSet3','SM1','SM5','SM6','SM9','SM10','SM14','SrM16','SM18','SM19']

# %%
n_df = df.drop(columns=uf_columns)

# %%
n_df
# Out:
#        Cycle     SM2      SM3      SM4     SM7      SM8   SM11    SM12  \
# 0          1  641.82  1589.70  1400.60  554.36  2388.06  47.47  521.66
# 1          2  642.15  1591.82  1403.14  553.75  2388.04  47.49  522.28
# 2          3  642.35  1587.99  1404.20  554.26  2388.08  47.27  522.42
# 3          4  642.35  1582.79  1401.87  554.45  2388.11  47.13  522.86
# 4          5  642.37  1582.85  1406.22  554.00  2388.06  47.28  522.19
# ...      ...     ...      ...      ...     ...      ...    ...     ...
# 61244    251  605.33  1516.36  1315.28  404.59  2319.66  46.08  380.16
# 61245    252  643.42  1598.92  1426.77  567.59  2388.47  48.04  535.02
# 61246    253  643.68  1607.72  1430.56  569.04  2388.51  48.24  535.41
# 61247    254  555.77  1381.29  1148.18  199.93  2223.78  42.53  187.92
# 61248    255  549.85  1369.75  1147.45  142.47  2212.52  42.60  134.32
#
#           SM13    SM15  SM17   SM20     SM21  label
# 0      2388.02  8.4195   392  39.06  23.4190      0
# ...

# %%
X = n_df.iloc[:,0:-1]
y = n_df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 10)

# %%
# random forest mode
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# perfomance validation
y_pred = rf.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8813295086056373

# %%
# hyperparameter optimization 
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators=[200, 400, 300]
# Maximum number of levels in tree
max_depth= [10, 20, 30]
# Max number of samples given to each tree 
max_samples= [0.2,0.3,0.4 ]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth,
               'max_samples': max_samples}
print(random_grid)
# Out:
# {'n_estimators': [200, 400, 300], 'max_depth': [10, 20, 30], 'max_samples': [0.2, 0.3, 0.4]}

# %%
rf = RandomForestClassifier()
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, cv = 3,n_jobs=-1)

# %%
rf_random.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'max_depth': [10, 20, 30],
#                                         'max_samples': [0.2, 0.3, 0.4],
#                                         'n_estimators': [200, 400, 300]})

# %%
rf_random.best_score_
# Out:
# 0.8782261805544715

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 200, 'max_samples': 0.3, 'max_depth': 20}

# %%
rf_rand = RandomForestClassifier(n_estimators=200,max_samples=0.3,max_depth= 20)
rf_rand.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, max_samples=0.3, n_estimators=200)

# %%
y_pred_rf = rf_rand.predict(X_test)

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.8811112496882015

# %%
import pickle
filename = "Model_2.pickle"
pickle.dump(rf_rand,open(filename,'wb'))

# %%
# testing model using test dataset
